# %%
# !pip install gTTS pyttsx3 playsound soundfile transformers datasets sentencepiece
# Out:
# ...
#   Obtaining dependency information for gTTS from https://files.pythonhosted.org/packages/a7/ef/190f64a4edeb13165e3c598a08f06a2ae80cdae0aa208c96c20efdb7ad4b/gTTS-2.4.0-py3-none-any.whl.metadata
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#      - -------------------------------------- 0.0/1.0 MB 1.9 MB/s eta 0:00:01
#      ------ --------------------------------- 0.2/1.0 MB 2.1 MB/s eta 0:00:01
#      ------------ --------------------------- 0.3/1.0 MB 2.4 MB/s eta 0:00:01
#      ------------------- -------------------- 0.5/1.0 MB 2.8 MB/s eta 0:00:01
#      -------------------------- ------------- 0.7/1.0 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------- ----- 0.9/1.0 MB 3.2 MB/s eta 0:00:01
#      ---------------------------------------  1.0/1.0 MB 3.2 MB/s eta 0:00:01
# ...

# %%
import gtts
from playsound import playsound

# %%
# make request to google to get synthesis
tts = gtts.gTTS("Hello data science team, this is a test of the text to speech system.")

# %%
# save the audio file
tts.save("hello_datascience_team.mp3")

# %%
tts.save("hello_datascience_team.wav")
